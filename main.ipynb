# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('dataset\preprocessed_aqi.csv')
df.rename(columns={df.columns[0]: 'Date'}, inplace=True) 
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df.index.freq = 'MS'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\HP\AppData\Local\Temp\ipykernel_31132\718960968.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('dataset\preprocessed_aqi.csv')

# %%
print(df.head())
# Out:
#             Ahmedabad_AQI  Aizawl_AQI  Amaravati_AQI  Amritsar_AQI  \
# Date
# 2015-01-01     350.333333         NaN            NaN           NaN
# 2015-02-01     520.640000         NaN            NaN           NaN
# 2015-03-01     418.571429         NaN            NaN           NaN
# 2015-04-01     308.640000         NaN            NaN           NaN
# 2015-05-01     263.466667         NaN            NaN           NaN
#
#             Bengaluru_AQI  Bhopal_AQI  Brajrajnagar_AQI  Chandigarh_AQI  \
# Date
# 2015-01-01            NaN         NaN               NaN             NaN
# 2015-02-01            NaN         NaN               NaN             NaN
# 2015-03-01     130.545455         NaN               NaN             NaN
# 2015-04-01     113.733333         NaN               NaN             NaN
# 2015-05-01     102.774194         NaN               NaN             NaN
#
#             Chennai_AQI  Coimbatore_AQI  ...  Kochi_AQI  Kolkata_AQI  \
# Date                                     ...
# 2015-01-01          NaN             NaN  ...        NaN          NaN
# 2015-02-01          NaN             NaN  ...        NaN          NaN
# 2015-03-01   363.800000             NaN  ...        NaN          NaN
# 2015-04-01   175.862069             NaN  ...        NaN          NaN
# 2015-05-01   176.129032             NaN  ...        NaN          NaN
#
#             Lucknow_AQI  Mumbai_AQI  Patna_AQI  Shillong_AQI  Talcher_AQI  \
# Date
# 2015-01-01          NaN         NaN        NaN           NaN          NaN
# 2015-02-01          NaN         NaN        NaN           NaN          NaN
# 2015-03-01   264.272727         NaN        NaN           NaN          NaN
# 2015-04-01   118.586207         NaN        NaN           NaN          NaN
# 2015-05-01   137.000000         NaN        NaN           NaN          NaN
#
#             Thiruvananthapuram_AQI  Visakhapatnam_AQI   India_AQI
# Date
# 2015-01-01                     NaN                NaN  346.311828
# 2015-02-01                     NaN                NaN  424.284286
# 2015-03-01                     NaN                NaN  258.875688
# 2015-04-01                     NaN                NaN  193.815995
# 2015-05-01                     NaN                NaN  193.556272
#
# [5 rows x 27 columns]

# %%
ax= df[['India_AQI']].plot(figsize=(12,8),grid=True,lw=2,color='Red')
ax.autoscale(enable=True, axis='both', tight=True)

# %%
df_2019=df['2019-01-01':'2020-01-01']
df_2019.head()
# Out:
#             Ahmedabad_AQI  Aizawl_AQI  Amaravati_AQI  Amritsar_AQI  \
# Date
# 2019-01-01     755.516129         NaN     218.612903     94.633333
# 2019-02-01     560.535714         NaN     114.464286     94.892857
# 2019-03-01     601.741935         NaN      79.967742     99.733333
# 2019-04-01     633.518519         NaN      78.133333    112.000000
# 2019-05-01     412.769231         NaN     106.777778    113.258065
#
#             Bengaluru_AQI  Bhopal_AQI  Brajrajnagar_AQI  Chandigarh_AQI  \
# Date
# 2019-01-01     116.806452         NaN        259.967742             NaN
# 2019-02-01     106.250000         NaN        208.259259             NaN
# 2019-03-01     122.129032         NaN        186.870968             NaN
# 2019-04-01     124.300000         NaN        190.562500             NaN
# 2019-05-01     105.387097         NaN        130.464286             NaN
#
#             Chennai_AQI  Coimbatore_AQI  ...  Kochi_AQI  Kolkata_AQI  \
# Date                                     ...
# 2019-01-01   131.000000             NaN  ...        NaN   360.838710
# 2019-02-01   118.071429             NaN  ...        NaN   266.071429
# 2019-03-01   101.419355             NaN  ...        NaN   157.774194
# 2019-04-01    87.533333             NaN  ...        NaN    86.800000
# 2019-05-01   103.612903             NaN  ...        NaN    88.548387
#
#             Lucknow_AQI  Mumbai_AQI   Patna_AQI  Shillong_AQI  Talcher_AQI  \
# Date
# 2019-01-01   315.516129  165.516129  405.290323           NaN   289.400000
# 2019-02-01   243.071429  149.821429  296.107143           NaN   322.555556
# 2019-03-01   217.645161  123.483871  214.032258           NaN   189.888889
# 2019-04-01   217.700000   98.066667  151.100000           NaN   142.160000
# 2019-05-01   184.096774   87.870968  170.806452           NaN   130.413793
#
#             Thiruvananthapuram_AQI  Visakhapatnam_AQI   India_AQI
# Date
# 2019-01-01              128.161290         263.129032  264.985723
# 2019-02-01               88.428571         152.307692  197.428013
# 2019-03-01               88.838710          93.033333  168.896689
# 2019-04-01               69.933333          92.827586  157.218977
# 2019-05-01               75.419355         123.933333  146.614816
#
# [5 rows x 27 columns]

# %%
df_2019.isna().sum()
# Out:
# Ahmedabad_AQI              0
# Aizawl_AQI                13
# Amaravati_AQI              1
# Amritsar_AQI               0
# Bengaluru_AQI              0
# Bhopal_AQI                 8
# Brajrajnagar_AQI           0
# Chandigarh_AQI             8
# Chennai_AQI                0
# Coimbatore_AQI             5
# Delhi_AQI                  0
# Ernakulam_AQI             12
# Gurugram_AQI               0
# Guwahati_AQI               1
# Hyderabad_AQI              0
# Jaipur_AQI                 0
# Jorapokhar_AQI             1
# Kochi_AQI                 12
# Kolkata_AQI                0
# Lucknow_AQI                0
# Mumbai_AQI                 0
# Patna_AQI                  0
# Shillong_AQI               8
# Talcher_AQI                0
# Thiruvananthapuram_AQI     0
# Visakhapatnam_AQI          0
# India_AQI                  0
# dtype: int64

# %%
df_2019=df_2019.drop(['Aizawl_AQI','Ernakulam_AQI','Kochi_AQI'],axis=1)

# %%
AQI_2019=df_2019.mean(axis=0)

# %%
print(AQI_2019.describe)
# Out:
# <bound method NDFrame.describe of Ahmedabad_AQI             498.673857
# Amaravati_AQI              94.870065
# Amritsar_AQI              108.971576
# Bengaluru_AQI              91.991935
# Bhopal_AQI                152.160199
# Brajrajnagar_AQI          148.056790
# Chandigarh_AQI            125.512430
# Chennai_AQI               101.903261
# Coimbatore_AQI             76.392856
# Delhi_AQI                 238.050461
# Gurugram_AQI              198.853334
# Guwahati_AQI              142.567454
# Hyderabad_AQI              94.866377
# Jaipur_AQI                119.949486
# Jorapokhar_AQI            154.076384
# Kolkata_AQI               150.024684
# Lucknow_AQI               208.207480
# Mumbai_AQI                112.763849
# Patna_AQI                 221.437303
# Shillong_AQI               45.730159
# Talcher_AQI               175.527653
# Thiruvananthapuram_AQI     75.479911
# Visakhapatnam_AQI         122.215757
# India_AQI                 156.599421
# dtype: float64>

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
bplot = sns.boxplot( data=df_2019,  width=0.75,palette="GnBu_d")
plt.ylabel('AQI')
bplot.grid(True)

# %%
plt.figure(figsize=(20,8))
plt.xticks(rotation=90)
plt.ylabel('AQI')
sns.barplot(x=AQI_2019.index, y=AQI_2019.values, palette="GnBu_d")
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_31132\2635914931.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=AQI_2019.index, y=AQI_2019.values, palette="GnBu_d")

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
India_AQI=df['India_AQI']
result=seasonal_decompose(India_AQI,model='multiplicative')
result.plot();

# %%
from matplotlib import dates
ax=result.seasonal.plot(xlim=['2018-01-01','2020-02-10'],figsize=(20,8),lw=2)
ax.yaxis.grid(True)
ax.xaxis.grid(True)

# %% [markdown]
# Predictions

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima import auto_arima

# %%
opt_model = auto_arima(y=India_AQI,start_p=0,start_P=0,start_q=0,start_Q=0,seasonal=True, m=12)
print(opt_model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                   67
# Model:             SARIMAX(0, 1, 2)x(1, 0, [1], 12)   Log Likelihood                -316.908
# Date:                              Mon, 13 Jan 2025   AIC                            643.816
# Time:                                      00:12:57   BIC                            654.765
# Sample:                                  01-01-2015   HQIC                           648.143
#                                        - 07-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.0189      0.059      0.320      0.749      -0.097       0.135
# ma.L2         -0.8363      0.069    -12.077      0.000      -0.972      -0.701
# ar.S.L12       0.9444      0.062     15.221      0.000       0.823       1.066
# ma.S.L12      -0.5623      0.229     -2.458      0.014      -1.011      -0.114
# sigma2       694.3699    142.982      4.856      0.000     414.130     974.610
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.95   Jarque-Bera (JB):                 2.99
# Prob(Q):                              0.33   Prob(JB):                         0.22
# Heteroskedasticity (H):               0.38   Skew:                            -0.52
# Prob(H) (two-sided):                  0.03   Kurtosis:                         2.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
len(India_AQI)
# Out:
# 67

# %%
#Divide into train and test
train = India_AQI[:41]
test = India_AQI[42:54]

# %%
model  = SARIMAX(train , order = (0, 1,2), seasonal_order=(1,0,1,12),)
results = model.fit()
results.summary()
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                            India_AQI   No. Observations:                   41
# Model:             SARIMAX(0, 1, 2)x(1, 0, [1], 12)   Log Likelihood                -199.018
# Date:                              Mon, 13 Jan 2025   AIC                            408.036
# Time:                                      00:19:33   BIC                            416.480
# Sample:                                  01-01-2015   HQIC                           411.089
#                                        - 05-01-2018
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.0708     14.494      0.005      0.996     -28.336      28.478
# ma.L2         -0.9289     13.515     -0.069      0.945     -27.417      25.559
# ar.S.L12       0.9210      0.130      7.072      0.000       0.666       1.176
# ma.S.L12      -0.4980      0.382     -1.303      0.192      -1.247       0.251
# sigma2       881.6099   1.27e+04      0.070      0.945    -2.4e+04    2.57e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.36   Jarque-Bera (JB):                 1.60
# Prob(Q):                              0.55   Prob(JB):                         0.45
# Heteroskedasticity (H):               0.27   Skew:                            -0.48
# Prob(H) (two-sided):                  0.03   Kurtosis:                         2.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
predictions = results.predict(start=42, end=53, typ='levels').rename('Predictions')
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
predictions.plot(legend=True)
test.plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error
RMSE=np.sqrt(mean_squared_error(predictions,test))
print('RMSE = ',RMSE)
print('Mean AQI',test.mean())
# Out:
# RMSE =  20.897197386991916
# Mean AQI 173.89252879752266

# %%
#dividing into train and test:
train=India_AQI[:53]
test=India_AQI[54:65]
# Forming the model:
model=SARIMAX(train,order=(0,1,2),seasonal_order=(1,0,1,12),)
results=model.fit()
results.summary()
#Obtaining predicted values:
predictions = results.predict(start=54, end=64, typ='levels').rename('Predictions')
#Plotting predicted values against the true values:
predictions.plot(legend=True)
test.plot(legend=True);
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %%
#Finding RMSE:
from sklearn.metrics import mean_squared_error
RMSE=np.sqrt(mean_squared_error(predictions,test))
print('RMSE = ',RMSE)
print('Mean AQI',test.mean())
# Out:
# RMSE =  43.74213470048134
# Mean AQI 129.50398238731393

# %%
# Forming the model:
model=SARIMAX(India_AQI,order=(0,1,2),seasonal_order=(1,0,1,12))
results=model.fit()
results.summary()
#Obtaining predicted values:
predictions = results.predict(start=66, end=77, typ='levels').rename('Predictions')
#Plotting predicted values against the true values:
predictions.plot(legend=True)
India_AQI.plot(legend=True,figsize=(12,8),grid=True);
# Out:
# C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\statsmodels\tsa\statespace\representation.py:374: FutureWarning: Unknown keyword arguments: dict_keys(['typ']).Passing unknown keyword arguments will raise a TypeError beginning in version 0.15.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Prophet

# %%
from prophet import Prophet

# %%
India_AQI=India_AQI.reset_index()
India_AQI.columns=['ds','y']

# %%
# Forming test/train data:
train=India_AQI[:-24]
test=India_AQI[-24:-12]
m = Prophet(seasonality_mode='multiplicative')
m.fit(train)
# Out:
# 00:31:07 - cmdstanpy - INFO - Chain [1] start processing
# 00:31:08 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=12,freq = 'MS')

# %%
forecast = m.predict(future)
m.plot(forecast);

# %%
RMSE=np.sqrt(mean_squared_error(forecast['yhat'][-12:],test['y']))
print('RMSE = ',RMSE)
print('Mean AQI',test['y'].mean())
# Out:
# RMSE =  22.62586719963371
# Mean AQI 173.7727029256349

# %%
m = Prophet(seasonality_mode='multiplicative',weekly_seasonality=False,daily_seasonality=False)
m.fit(India_AQI)
future = m.make_future_dataframe(periods=12,freq = 'MS')
forecast = m.predict(future)
m.plot(forecast);
# Out:
# 00:32:00 - cmdstanpy - INFO - Chain [1] start processing
# 00:32:01 - cmdstanpy - INFO - Chain [1] done processing

# %%
m.plot_components(forecast)

# %% [markdown]
# RNN

# %%
India_AQI=India_AQI.set_index('ds')
train=India_AQI[:-24]
test=India_AQI[-24:-12]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(train)
# Out:
# MinMaxScaler()

# %%
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
n_input = 24
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 from keras.preprocessing.sequence import TimeseriesGenerator
#       2 n_input = 24
#       3 n_features = 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import _tf_keras
#       9 from keras import activations
#      10 from keras import applications
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\_tf_keras\__init__.py:1
# ----> 1 from keras._tf_keras import keras
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\_tf_keras\keras\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras import activations
#       9 from keras import applications
#      10 from keras import callbacks
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\activations\__init__.py:8
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 8 from keras.src.activations import deserialize
#       9 from keras.src.activations import get
#      10 from keras.src.activations import serialize
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\__init__.py:1
# ----> 1 from keras.src import activations
#       2 from keras.src import applications
#       3 from keras.src import backend
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\activations\__init__.py:3
#       1 import types
# ----> 3 from keras.src.activations.activations import elu
#       4 from keras.src.activations.activations import exponential
#       5 from keras.src.activations.activations import gelu
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\activations\activations.py:1
# ----> 1 from keras.src import backend
#       2 from keras.src import ops
#       3 from keras.src.api_export import keras_export
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\backend\__init__.py:9
#       3 if backend() == "torch":
#       4     # When using the torch backend,
#       5     # torch needs to be imported first, otherwise it will segfault
#       6     # upon import.
#       7     import torch
# ----> 9 from keras.src.backend.common.dtypes import result_type
#      10 from keras.src.backend.common.keras_tensor import KerasTensor
#      11 from keras.src.backend.common.keras_tensor import any_symbolic_tensors
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\backend\common\__init__.py:2
#       1 from keras.src.backend.common import backend_utils
# ----> 2 from keras.src.backend.common.dtypes import result_type
#       3 from keras.src.backend.common.variables import AutocastScope
#       4 from keras.src.backend.common.variables import KerasVariable
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\backend\common\dtypes.py:5
#       3 from keras.src.api_export import keras_export
#       4 from keras.src.backend import config
# ----> 5 from keras.src.backend.common.variables import standardize_dtype
#       7 BOOL_TYPES = ("bool",)
#       8 INT_TYPES = (
#       9     "uint8",
#      10     "uint16",
#    (...)
#      16     "int64",
#      17 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\backend\common\variables.py:10
#       8 from keras.src.backend.common.stateless_scope import get_stateless_scope
#       9 from keras.src.backend.common.stateless_scope import in_stateless_scope
# ---> 10 from keras.src.utils.module_utils import tensorflow as tf
#      11 from keras.src.utils.naming import auto_name
#      14 class KerasVariable:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\utils\__init__.py:12
#      10 from keras.src.utils.io_utils import enable_interactive_logging
#      11 from keras.src.utils.io_utils import is_interactive_logging_enabled
# ---> 12 from keras.src.utils.model_visualization import model_to_dot
#      13 from keras.src.utils.model_visualization import plot_model
#      14 from keras.src.utils.numerical_utils import normalize
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\utils\model_visualization.py:8
#       6 from keras.src.api_export import keras_export
#       7 from keras.src.utils import io_utils
# ----> 8 from keras.src.utils import tree
#      10 try:
#      11     # pydot-ng is a fork of pydot that is better maintained.
#      12     import pydot_ng as pydot
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\keras\src\utils\tree.py:12
#      10 # Register backend-specific node classes
#      11 if backend() == "tensorflow":
# ---> 12     from tensorflow.python.trackable.data_structures import ListWrapper
#      14     optree.register_pytree_node(
#      15         ListWrapper,
#      16         lambda x: (x, None),
#      17         lambda metadata, children: ListWrapper(list(children)),
#      18         namespace="keras",
#      19     )
#      22 @keras_export("keras.tree.is_nested")
#      23 def is_nested(structure):
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
#To give an idea of what generator file holds:
X,y = generator[0]

# %%
# We can see that the x array gives the list of values that we are going to predict y of:
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')

# %% [markdown]
# Creating the model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# defining the model(note that  I am using a very basic model here, a 2 layer model only):
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

model.summary()

# %% [markdown]
# Fitting the model

# %%
# Fitting the model with the generator object:
model.fit_generator(generator,epochs=250)

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    
    current_pred = model.predict(current_batch)[0]
    
    
    test_predictions.append(current_pred) 
    
    
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions

# %%
test.plot(figsize=(12,8))
plt.plot(true_predictions)

# %%
RMSE=np.sqrt(mean_squared_error(test['y'],test['Predictions']))
print('RMSE = ',RMSE)
print('India_AQI=',India_AQI['y'].mean())

# %% [markdown]
# Forecasting into future

# %%
scaler.fit(India_AQI)
scaled_India_AQI=scaler.transform(India_AQI)

# %%
generator = TimeseriesGenerator(scaled_India_AQI, scaled_India_AQI, length=n_input, batch_size=1)

# %%
model.fit_generator(generator,epochs=250)

# %%
test_predictions = []

first_eval_batch = scaled_India_AQI[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    
    current_pred = model.predict(current_batch)[0]
    
    
    test_predictions.append(current_pred) 
    
    
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
true_predictions=true_predictions.flatten()

# %%
true_preds=pd.DataFrame(true_predictions,columns=['Forecast'])
true_preds=true_preds.set_index(pd.date_range('2020-06-01',periods=12,freq='MS'))

# %%
true_preds

# %%
plt.figure(figsize=(20,8))
plt.grid(True)
plt.plot( true_preds['Forecast'])
plt.plot( India_AQI['y'])
